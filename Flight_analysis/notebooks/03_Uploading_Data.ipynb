# %% [markdown]
#  # Notebook description
#
#  The role of this notebook is to adjust the data structure from the source files to a format compatible with `Postgres`, and then upload them to the server.

# %% [markdown]
# ## Notepad configuration

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import pandas as pd 
import os
from dotenv import  load_dotenv

# %%
load_dotenv("D:\Python\devcontainer\.env") #loading postgre password from .env file
# Out:
# True

# %% [markdown]
# Create url and engine

# %%
url = URL.create(
    "postgresql+psycopg2",
    username='postgres',
    password=os.getenv("POSTGRES_PASSWORD"),  
    host='localhost',
    database='postgres',
)
engine = create_engine(url)

# %% [markdown]
# Loading frames into the workspace

# %%
def load_raw_data(file_name):
    file_name.columns = [column.lower() for column in file_name.columns]
    return file_name

# %% [markdown]
# Uploading individual files to frames

# %%
df_aircraft = pd.read_csv('aircraft.csv')

df_airport = pd.read_csv('airport_list.csv')

df_weather = pd.read_csv('airport_weather.csv')

df_flight = pd.read_csv('flight.csv')

# %%
load_raw_data(df_aircraft)
# Out:
#       manufacture_year tail_num  number_of_seats
# 0                 1944   N54514              0.0
# 1                 1945   N1651M              0.0
# 2                 1953   N100CE              0.0
# 3                 1953   N141FL              0.0
# 4                 1953   N151FL              0.0
# ...                ...      ...              ...
# 7378              2019   N14011            337.0
# 7379              2019   N16008            337.0
# 7380              2019   N16009            337.0
# 7381              2019   N2250U            276.0
# 7382              2019   N2749U            276.0
#
# [7383 rows x 3 columns]

# %%
df_aircraft.sample()
# Out:
#      manufacture_year tail_num  number_of_seats
# 382              1990   N967DL            149.0

# %%
load_raw_data(df_airport)
# Out:
#     origin_airport_id              display_airport_name  origin_city_name  \
# 0               11638               Fresno Air Terminal        Fresno, CA
# 1               13342            General Mitchell Field     Milwaukee, WI
# 2               13244             Memphis International       Memphis, TN
# 3               15096    Syracuse Hancock International      Syracuse, NY
# 4               10397                 Atlanta Municipal       Atlanta, GA
# ..                ...                               ...               ...
# 92              13198         Kansas City International   Kansas City, MO
# 93              10423  Austin - Bergstrom International        Austin, TX
# 94              15370               Tulsa International         Tulsa, OK
# 95              13303               Miami International         Miami, FL
# 96              10693        Myrtle Beach International  Myrtle Beach, SC
#
#                                                  name
# 0                FRESNO YOSEMITE INTERNATIONAL, CA US
# 1                   MILWAUKEE MITCHELL AIRPORT, WI US
# 2                MEMPHIS INTERNATIONAL AIRPORT, TN US
# 3       SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US
# 4   ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ..                                                ...
# 92           KANSAS CITY INTERNATIONAL AIRPORT, MO US
# 93      AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 94     OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US
# 95                 MIAMI INTERNATIONAL AIRPORT, FL US
# 96                          NORTH MYRTLE BEACH, SC US
#
# [97 rows x 4 columns]

# %%
df_airport.sample()
# Out:
#     origin_airport_id        display_airport_name  origin_city_name  \
# 87              14262  Palm Springs International  Palm Springs, CA
#
#                                       name
# 87  DESERT RESORTS REGIONAL AIRPORT, CA US

# %%
load_raw_data(df_weather)
# Out:
#        wt18      station                                               name  \
# 0       NaN  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 1       NaN  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2       NaN  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 3       NaN  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 4       NaN  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ...     ...          ...                                                ...
# 46221   NaN  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46222   NaN  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46223   NaN  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46224   NaN  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46225   NaN  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
#
#              date   awnd  prcp  snow  snwd  tavg  tmax  ...    pgtm  wt10  \
# 0      2019-01-01   4.70  0.14   0.0   0.0  64.0  66.0  ...     NaN   NaN
# 1      2019-01-02   4.92  0.57   0.0   0.0  56.0  59.0  ...     NaN   NaN
# 2      2019-01-03   5.37  0.15   0.0   0.0  52.0  55.0  ...     NaN   NaN
# 3      2019-01-04  12.08  1.44   0.0   0.0  56.0  66.0  ...     NaN   NaN
# 4      2019-01-05  13.42  0.00   0.0   0.0  49.0  59.0  ...     NaN   NaN
# ...           ...    ...   ...   ...   ...   ...   ...  ...     ...   ...
# 46221  2020-03-27   3.58  0.21   NaN   NaN   NaN  59.0  ...   146.0   NaN
# 46222  2020-03-28   6.93  1.29   NaN   NaN   NaN  77.0  ...  1535.0   NaN
# 46223  2020-03-29  16.55  0.02   NaN   NaN   NaN  78.0  ...  1408.0   NaN
# 46224  2020-03-30  13.42  0.00   NaN   NaN   NaN  57.0  ...   817.0   NaN
# 46225  2020-03-31   3.80  0.06   NaN   NaN   NaN  47.0  ...   110.0   NaN
#
#        wesd  sn32  sx32  psun  tsun  tobs  wt07  wt11
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 46221   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46222   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46223   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46224   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46225   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [46226 rows x 33 columns]

# %%
df_weather.sample()
# Out:
#        wt18      station                                   name        date  \
# 30079   NaN  USW00022521  HONOLULU INTERNATIONAL AIRPORT, HI US  2019-10-06
#
#        awnd  prcp  snow  snwd  tavg  tmax  ...  pgtm  wt10  wesd  sn32  sx32  \
# 30079  6.49   0.0   NaN   NaN  79.0  86.0  ...   NaN   NaN   NaN   NaN   NaN
#
#        psun  tsun  tobs  wt07  wt11
# 30079   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 33 columns]

# %%
load_raw_data(df_flight)
# Out:
#          month  day_of_month  day_of_week op_unique_carrier tail_num  \
# 0            1            20            7                WN   N204WN
# 1            1            20            7                WN   N8682B
# 2            1            20            7                WN   N717SA
# 3            1            20            7                WN   N709SW
# 4            1            20            7                WN   N7864B
# ...        ...           ...          ...               ...      ...
# 1386115      3            26            4                DL   N350DN
# 1386116      3            26            4                DL   N908DE
# 1386117      3            26            4                DL      NaN
# 1386118      3            26            4                DL   N352NW
# 1386119      3            26            4                DL   N352DN
#
#          op_carrier_fl_num  origin_airport_id  dest_airport_id  crs_dep_time  \
# 0                      682              10397            11292           605
# 1                     2622              10397            11292          2120
# 2                     2939              10397            11292          1800
# 3                     3848              10397            11292          1355
# 4                     1352              10397            11697          1125
# ...                    ...                ...              ...           ...
# 1386115               1982              13303            12953          1956
# 1386116               1987              13303            10397          1120
# 1386117               1998              13303            10397          1817
# 1386118               2025              13303            10397          1937
# 1386119               2151              13303            12953           700
#
#          dep_time  ...  crs_elapsed_time actual_elapsed_time  distance  \
# 0           602.0  ...               205               204.0      1199
# 1          2114.0  ...               210               205.0      1199
# 2          1807.0  ...               210               220.0      1199
# 3          1354.0  ...               205               204.0      1199
# 4          1125.0  ...               120               124.0       581
# ...           ...  ...               ...                 ...       ...
# 1386115    1944.0  ...               183               169.0      1096
# 1386116    1117.0  ...               121               109.0       594
# 1386117       NaN  ...               125                 NaN       594
# 1386118    1928.0  ...               123               107.0       594
# 1386119       NaN  ...               183                 NaN      1096
#
#          distance_group  year carrier_delay  weather_delay  nas_delay  \
# 0                     5  2019           NaN            NaN        NaN
# 1                     5  2019           NaN            NaN        NaN
# 2                     5  2019           4.0            0.0       10.0
# 3                     5  2019           NaN            NaN        NaN
# 4                     3  2019           NaN            NaN        NaN
# ...                 ...   ...           ...            ...        ...
# 1386115               5  2020           NaN            NaN        NaN
# 1386116               3  2020           NaN            NaN        NaN
# 1386117               3  2020           NaN            NaN        NaN
# 1386118               3  2020           NaN            NaN        NaN
# 1386119               5  2020           NaN            NaN        NaN
#
#          security_delay  late_aircraft_delay
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   0.0                  3.0
# 3                   NaN                  NaN
# 4                   NaN                  NaN
# ...                 ...                  ...
# 1386115             NaN                  NaN
# 1386116             NaN                  NaN
# 1386117             NaN                  NaN
# 1386118             NaN                  NaN
# 1386119             NaN                  NaN
#
# [1386120 rows x 27 columns]

# %%
df_flight.sample()
# Out:
#          month  day_of_month  day_of_week op_unique_carrier tail_num  \
# 1189474      2            17            7                B6   N969JT
#
#          op_carrier_fl_num  origin_airport_id  dest_airport_id  crs_dep_time  \
# 1189474               1415              12478            14771          2000
#
#          dep_time  ...  crs_elapsed_time actual_elapsed_time  distance  \
# 1189474    1958.0  ...               412               406.0      2586
#
#          distance_group  year carrier_delay  weather_delay  nas_delay  \
# 1189474              11  2019           NaN            NaN        NaN
#
#          security_delay  late_aircraft_delay
# 1189474             NaN                  NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Exporting data to a database

# %%
def export_table_to_df(table_name, df):
    df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

# %% [markdown]
#  ## Uploading data

# %% [markdown]
#  ### Uploading `aircraft_df` to the `aircraft` table.

# %%
df_aircraft.to_sql(name='aircraft', con=engine, if_exists='append', index=False)
# Out:
# 383

# %% [markdown]
#  ### Uploading `airport_weather_df` to the `airport_weather` table.

# %%
df_weather.to_sql(name='airport_weather', con=engine, if_exists='append', index=False)
# Out:
# 686

# %% [markdown]
#  ### Uploading `flight_df` to the `flight` table.

# %%
df_flight.to_sql(name='flight', con=engine, if_exists='append', index=False)
# Out:
# 120

# %% [markdown]
#  ### Uploading `airport_list_df` to the `airport_list` table.

# %%
df_airport.to_sql(name='airport_list', con=engine, if_exists='append', index=False)
# Out:
# 97
